# %% [markdown]
# # Data Visualization Using Python
#
# Data sales_data_sample.csv diambil dari https://www.kaggle.com/kyanyoga/sample-sales-data
#
# Sebagai seorang Data Analyst, anda diberikan tugas untuk melakukan visualisasi data yang akan dipresentasikan kepada Manajer perusahaan. Tunjukkan kemampuanmu sebagai seorang Data Analyst!

# %% [markdown]
# ## Mengkoneksikan Colab dengan Gdrive

# %%
# from google.colab import drive
# drive.mount('/content/gdrive')

# %% [markdown]
# ## Import Packages

# %%
# !pip install plotly==4.14.3

# %%
# Import package
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
import numpy as np

# %% [markdown]
# ## Setting Path

# %%
# im using local env

# %% [markdown]
# ## Gunakan data sales_data_sample.csv

# %%
data = pd.read_csv('sales_data_sample.csv',encoding='ISO-8859-1')
data.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %% [markdown]
# Kolom yang akan digunakan selanjutnya adalah:
# - ORDERNUMBER
# - QUANTITYORDERED
# - PRICEEACH
# - ORDERLINENUMBER
# - SALES
# - ORDERDATE
# - STATUS
# - YEAR_ID
# - PRODUCTLINE

# %%
newdata = data[['ORDERNUMBER','QUANTITYORDERED','PRICEEACH','ORDERLINENUMBER','SALES','ORDERDATE','STATUS','YEAR_ID','PRODUCTLINE']]
newdata
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  YEAR_ID  PRODUCTLINE
# ...

# %% [markdown]
# Buatlah kolom baru bernama Date yang berasal dari kolom ORDERDATE!

# %%
newdata['DATE'] = newdata['ORDERDATE']
newdata
# Out:
# C:\Users\Tangbim\AppData\Local\Temp\ipykernel_4144\524164583.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdata['DATE'] = newdata['ORDERDATE']
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# ...

# %% [markdown]
# Hapus kolom ORDERDATE!

# %%
newdata = newdata.drop('ORDERDATE', axis=1)
newdata
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#         STATUS  YEAR_ID  PRODUCTLINE             DATE
# ...

# %% [markdown]
# Case 1 :
# Dari data sales, tampilkan :<br>
# a. Bar chart dari YEAR_ID<br>
# b. Bar Chart dari PRODUCTLINE<br>
# c. Bar Chart dari STATUS<br>
# d. line plot dari SALES terhadap Date<br>
# e. Interpretasikan insight  yang didapatkan

# %%
#  a
sns.catplot(x="YEAR_ID", kind="count", palette="ch:.42", data=newdata)
plt.show()

# %%
#  b
sns.catplot(x="PRODUCTLINE", kind="count", palette="ch:.42", data=newdata, height=10)
plt.show()

# %%
#  c
sns.catplot(x="STATUS", kind="count", palette="ch:.42", data=newdata)
plt.show()

# %%
# d
newdata['DATE'] = pd.to_datetime(newdata['DATE'])
newdata = newdata.sort_values('DATE')
plt.plot(newdata['DATE'], newdata['SALES'])
plt.title('Line Plot of SALES by DATE')
plt.xlabel('Date')
plt.ylabel('Sales')
plt.show()

# %%
# e
print("Berdasarkan data di atas, dapat disimpulkan bahwa")
print("1. Transaksi yang terjadi paling banyak adalah pada tahun 2003 dan terendah di tahun 2005 ")
print("2. Classic cars adalah kendaraan yang paling diminati dibandingkan kendaraan lainnya ")
print("3. Lebih banyak transaksi yang sukes dibandingkan yang batal atau belum terkirim")
print("4. Persebaran transaksi terbanyak terjadi pada interval tahun 2005 bulan 2 hingga 7")
# Out:
# Berdasarkan data di atas, dapat disimpulkan bahwa
# 1. Transaksi yang terjadi paling banyak adalah pada tahun 2003 dan terendah di tahun 2005
# 2. Classic cars adalah kendaraan yang paling diminati dibandingkan kendaraan lainnya
# 3. Lebih banyak transaksi yang sukes dibandingkan yang batal atau belum terkirim
# 4. Persebaran transaksi terbanyak terjadi pada interval tahun 2005 bulan 2 hingga 7

# %% [markdown]
# Case 2:
# Berdasarkan data sales, tampilkan statistika deskriptif secara boxplot terkait penyebaran dari rata rata penjualan untuk masing-masing productline dalam 1 layer, lalu interpretasikan hasil yang didapatkan dari visual tersebut.

# %%
sales = newdata[['SALES','PRODUCTLINE']]
sales.boxplot(column=['SALES'], by=['PRODUCTLINE'], figsize=(10, 8))
plt.show()

print("Dari Boxplot tersebut dapat disimpulkan bahwa:")
print("1. Vintage cars memiliki sales representatif yang tinggi di atas boxplot")
print("2. Trains memiliki sales yang plaing rendah")
# Out:
# Dari Boxplot tersebut dapat disimpulkan bahwa:
# 1. Vintage cars memiliki sales representatif yang tinggi di atas boxplot
# 2. Trains memiliki sales yang plaing rendah

# %% [markdown]
# Case 3 :
# Bagaimana hubungan SALES dan PRICEEACH? Tunjukkan plotnya dan berikan intepretasi hasilnya!

# %%
plt.scatter(newdata['PRICEEACH'], newdata['SALES'])
plt.xlabel('PRICEEACH')
plt.ylabel('SALES')
plt.show()

print("Pada penyebaran tersebut diperoleh fakta bahwa untuk product dengan harga satuan 100 memiliki sales tertinggi")
print("Hal ini juga diimbangi dengan persebaran data yang cukup merata dan cenderung naik setiap varian harga satuannya")
# Out:
# Pada penyebaran tersebut diperoleh fakta bahwa untuk product dengan harga satuan 100 memiliki sales tertinggi
# Hal ini juga diimbangi dengan persebaran data yang cukup merata dan cenderung naik setiap varian harga satuannya

# %% [markdown]
# Case 4:<br>
# a. Hitunglah persentase sales pada masing-masing status <br>
# b. Hitunglah persentase cumulatif sales masing-masing status <br>
# c. Buatlah pareto chart dan berikan intepretasinya

# %%
# hitung total sales
total_sales = newdata['SALES'].sum()

# hitung persentase sales pada masing-masing status
sales_by_status = newdata.groupby('STATUS')['SALES'].sum()
sales_percentage = sales_by_status / total_sales * 100

print(sales_percentage)
# Out:
# STATUS
# Cancelled      1.938550
# Disputed       0.719780
# In Process     1.442593
# On Hold        1.783971
# Resolved       1.502281
# Shipped       92.612826
# Name: SALES, dtype: float64

# %%
# hitung persentase cumulatif sales masing-masing status
cumulative_percentage = sales_percentage.cumsum()

print(cumulative_percentage)
# Out:
# STATUS
# Cancelled       1.938550
# Disputed        2.658330
# In Process      4.100922
# On Hold         5.884893
# Resolved        7.387174
# Shipped       100.000000
# Name: SALES, dtype: float64

# %%
# buat pareto chart
fig, ax1 = plt.subplots()
ax2 = ax1.twinx()
ax1.bar(sales_percentage.index, sales_percentage.values, color='tab:blue')
ax2.plot(sales_percentage.index, cumulative_percentage.values, color='tab:red', marker='o')
ax2.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:.0%}".format(x/100)))
ax1.set_xlabel('Status')
ax1.set_ylabel('Sales Percentage')
ax2.set_ylabel('Cumulative Percentage')
ax1.tick_params(axis='x', rotation=45)

plt.show()
