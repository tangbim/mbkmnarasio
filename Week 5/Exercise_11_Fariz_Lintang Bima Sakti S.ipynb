# %% [markdown]
# # Breakout Room Study Case
# Panggil kembali data **house_pricing.csv**. Sebelumnya anda telah melakukan survey mengenai harga rumah dan kondisi rumah. Anda berfikir bahwa anda memerlukan informasi tambahan mengenai luas area, garage area, street, dan neighborhood. Anda telah menyiapkan beberapa pertanyaan mengenai riset anda nantinya. List pertanyaan tersebut seperti berikut :
# 1. Berapa rata-rata dan standar deviasi dari luas area dan luas garasi yang ditawarkan?
# 2. Berapakah rata-rata luas area dan garasi berdasarkan neighborhood dan street ?
# 3. Kira-kira pada kisaran berapakah luas area dan garasi untuk jalan dengan tipe pave?

# %% [markdown]
# ## Connect Colab dengan Gdrive

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %% [markdown]
# ## Import Packages

# %%
import os
import pandas as pd
import numpy as np
from numpy import random
from numpy import mean
from numpy.random import seed
import scipy.stats as stats
from scipy.stats import ttest_1samp, ttest_ind
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Setting Directory

# %%
# im using local env

# %% [markdown]
# ## Load Data

# %%
data = pd.read_csv('house_pricing.csv')
data
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %% [markdown]
# ## Pertanyaan 1
# Mencari rata-rata dan standar deviasi dari luas area dan luas garasi yang ditawarkan.

# %%
stdLotArea = data['LotArea'].std()
meanLotArea = data['LotArea'].mean()
print(f"Standar deviasi garasi berdasarkan data adalah {stdLotArea}")
print(f"Rata-rata luas garasi berdasarkan data adalah {meanLotArea}\n")

stdGarageArea = data['GarageArea'].std()
meanGarageArea = data['GarageArea'].mean()
print(f"Rata-rata luas garasi berdasarkan data adalah {meanGarageArea}")
print(f"Standar deviasi luas garasi berdasarkan data adalah {stdGarageArea}")
# Out:
# Standar deviasi garasi berdasarkan data adalah 9981.26493237915
# Rata-rata luas garasi berdasarkan data adalah 10516.828082191782
#
# Rata-rata luas garasi berdasarkan data adalah 472.9801369863014
# Standar deviasi luas garasi berdasarkan data adalah 213.80484145338042

# %% [markdown]
# ## Pertanyaan 2
# Mencari rata-rata luas area dan garasi berdasarkan neighborhood dan street

# %%
meanLotAreaGarageArea = data.groupby(['Neighborhood', 'Street']).mean()

res = meanLotAreaGarageArea[['LotArea', 'GarageArea']]

res
# Out:
# C:\Users\Tangbim\AppData\Local\Temp\ipykernel_15616\1394994940.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   meanLotAreaGarageArea = data.groupby(['Neighborhood', 'Street']).mean()
#                           LotArea  GarageArea
# Neighborhood Street
# Blmngtn      Pave     3398.176471  502.764706
# Blueste      Pave     1625.000000  457.000000
# BrDale       Pave     1801.000000  284.000000
# BrkSide      Pave     7360.413793  303.241379
# ClearCr      Pave    30875.750000  468.428571
# CollgCr      Pave     9619.146667  552.580000
# Crawfor      Pave    11809.686275  410.078431
# Edwards      Grvl    11841.000000    0.000000
#              Pave    10202.262626  329.494949
# Gilbert      Pave    11379.151899  452.645570
# IDOTRR       Grvl    11728.000000  756.000000
# ...

# %% [markdown]
# ## Pertanyaan 3
# Mencari kisaran luas area dan garasi untuk jalan dengan tipe pave

# %%
# kisaran = range 
# rumus kisaran adalah data max - data min
def searchRange (data) :
      rangeKisaran = data.max() - data.min()
      return rangeKisaran

paveLotArea = data[data['Street']=='Pave']['LotArea']
rangeLotArea = searchRange(paveLotArea)

print(f"Jadi kisaran luas area dengan tipe pave adalah {rangeLotArea}")

paveGarageArea = data[data['Street']=='Pave']['GarageArea']
rangeGarageArea = searchRange(paveGarageArea)
print(f"Jadi kisaran luas area garasi dengan tipe pave adalah {rangeGarageArea}")
# Out:
# Jadi kisaran luas area dengan tipe pave adalah 213945
# Jadi kisaran luas area garasi dengan tipe pave adalah 1418
